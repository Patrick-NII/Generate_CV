# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('generated_cv_data.csv')

# %%
data.head()
# Out:
#    ID        nom    prenom                                            adresse  \
# 0   1    Rosales     Grant            0007 Derek Village\nHaleshire, ID 33510
# 1   2      Singh  Stefanie      84166 Arthur Expressway\nNorth Mary, LA 39002
# 2   3     Norton   Jessica  0994 Phillips Inlet Apt. 738\nEast Eric, AS 10587
# 3   4  Mccormick   Michael  2550 King Gardens Suite 433\nNew Stephenfort, ...
# 4   5      Baker  Patricia    68279 Evans Alley\nPort Taylorchester, WV 03212
#
#                        email   numero_de_telephone                intitule  \
# 0         gary44@example.com          911-352-4229      Personal assistant
# 1      matthew49@example.org     941-722-8863x1452     Biomedical engineer
# 2  michellelopez@example.com          700.504.8128          Teacher, music
# 3       ugregory@example.com          804.722.1885              Air broker
# 4   charleswhite@example.org  +1-875-344-9439x6840  Geologist, engineering
#
# ...
