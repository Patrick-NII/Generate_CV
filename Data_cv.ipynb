# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('generated_cv_data.csv')

# %%
data.head()
# Out:
#    ID       nom      prenom                                         adresse  \
# 0   1  Rousseau      Gérard       56, chemin Pasquier\n16454 Sainte Thierry
# 1   2   Hoareau  Bernadette       20, rue de Bourdon\n31475 Sainte Marcelle
# 2   3    Becker     Édouard  boulevard Suzanne Gros\n97237 Lombard-la-Forêt
# 3   4   Lemoine    Bertrand      20, avenue Lemoine\n40177 Saint Paulinedan
# 4   5     Neveu      Pierre                93, avenue Renault\n84661 Moreau
#
#                       email   numero_de_telephone  \
# 0  martinbonnin@example.org        02 32 30 13 44
# 1     aurelie81@example.net  +33 (0)5 16 10 66 33
# 2    hortense63@example.org            0130321996
# 3      ale-goff@example.org            0490427713
# 4        xclerc@example.com     +33 3 68 23 66 04
#
#                                             intitule   diplome  \
# 0                               secrétaire juridique   Réduire
# 1  inspecteur des douanes, des finances publiques...  Chercher
# ...
